# %% [markdown]
# <a href="https://colab.research.google.com/github/eddisonpham/Hierarchical-Scene-Captioner/blob/main/ActivityNetDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U datasets fsspec huggingface_hub
from datasets import load_dataset
ds = load_dataset("friedrichor/ActivityNet_Captions")
# Out:
# ...
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# activitynet_captions_train.json:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# activitynet_captions_val1.json: 0.00B [00:00, ?B/s]
# activitynet_captions_val2.json: 0.00B [00:00, ?B/s]
# ...
# Generating val2 split:   0%|          | 0/4885 [00:00<?, ? examples/s]

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['video_id', 'video', 'caption', 'source', 'duration', 'timestamps', 'sentences'],
#         num_rows: 10009
#     })
#     val1: Dataset({
#         features: ['video_id', 'video', 'caption', 'source', 'duration', 'timestamps', 'sentences'],
#         num_rows: 4917
#     })
#     val2: Dataset({
#         features: ['video_id', 'video', 'caption', 'source', 'duration', 'timestamps', 'sentences'],
#         num_rows: 4885
#     })
# })

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds['train'].to_json('/content/drive/MyDrive/AlgoverseMLLMResearch/Datasets')
ds['val1'].to_json('/content/drive/MyDrive/AlgoverseMLLMResearch/Datasets')
ds['val2'].to_json('/content/drive/MyDrive/AlgoverseMLLMResearch/Datasets/activitynet_val2.json')
# Out:
# ...
# Creating json from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# 3118849

# %%
ls
# Out:
# sample_data/

# %%
cd drive/MyDrive/AlgoverseMLLMResearch/Datasets
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/AlgoverseMLLMResearch/Datasets'
# /content
